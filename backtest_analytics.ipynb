# %%
import pandas as pd

# %%
df = pd.read_csv('backtest_results_30_70_online.csv')

# %%
df.head()
df.reset_index()
df.set_index('stock', inplace=True)

# %%
df.sort_values(by='stock', ascending=True, inplace=True)

# %%
df
# Out:
#             initial_capital  ending_value        returns   accuracy  \
# stock
# ACC                  500000  8.847029e+05      76.940581  37.735849
# ADANIENT             500000  9.498322e+08  189866.445300  47.457627
# ADANIGREEN           500000  3.238218e+06     547.643569  55.555556
# ADANIPORTS           500000  3.049403e+05     -39.011930  38.709677
# ADANITRANS           500000  5.008639e+06     901.727773  64.705882
# ...                     ...           ...            ...        ...
# ULTRACEMCO           500000  4.507800e+06     801.559949  51.063830
# UPL                  500000  1.815549e+06     263.109867  46.774194
# VEDL                 500000  2.884633e+05     -42.307341  31.250000
# WIPRO                500000  4.070978e+07    8041.956231  37.681159
# YESBANK              500000  2.524987e+06     404.997446  45.098039
#
#                   profit        avg_pl    avg_profit      avg_loss  \
# stock
# ...

# %%
df.to_csv('backtest_results_until_7_4_2022.csv')
