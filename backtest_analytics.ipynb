# %%
import pandas as pd

# %%
df = pd.read_csv('backtest_results.csv')

# %%
df.head()
df.reset_index()
df.set_index('stock', inplace=True)
del df['Unnamed: 0']

# %%
df.sort_values(by='returns', ascending=False, inplace=True)
del df['trade_list']

# %%
df
# Out:
#             initial_capital  ending_value       returns   accuracy  \
# stock
# ADANIENT             100000  3.150276e+07  31402.755015  64.130435
# VEDL                 100000  4.865961e+06   4765.960756  62.015504
# AUROPHARMA           100000  3.681324e+06   3581.323773  64.957265
# MCDOWELL-N           100000  9.773747e+05    877.374706  62.745098
# JINDALSTEL           100000  9.710290e+05    871.029023  66.037736
# ...                     ...           ...           ...        ...
# ONGC                 100000  3.341877e+04    -66.581231  54.545455
# IOC                  100000  2.557201e+04    -74.427990   0.000000
# YESBANK              100000  2.350248e+04    -76.497524  54.166667
# WIPRO                100000 -9.279272e+03   -109.279272  57.142857
# EICHERMOT            100000 -5.734453e+04   -157.344527  53.333333
#
#                   profit         avg_pl     avg_profit       avg_loss  \
# stock
# ADANIENT    3.140276e+07  341334.293637  853862.187310 -575003.455657
# ...

# %%
df.to_csv('backtest_results_sorted.csv')
